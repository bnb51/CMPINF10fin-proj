# %% [markdown]
# # Finding the Safest Neighborhood in Pittsburgh

# %% [markdown]
# In our project to find the best neighborhood in Pittsburgh, we decided to focus on an essential factor that affects everyone's well-being: safety. Safety is a broad notion that considers a variety of elements such as crime rates, law enforcement efficacy, and community trust. By prioritizing safety as our primary metric, we aim to shed light on places where residents may feel comfortable.
#
# To quantify safety, we utilized two primary datasets: one focusing on arrests in Pittsburgh and the other on firearm seizures. Both datasets provide valuable insights into public safety by highlighting areas with higher incidents of law enforcement interventions and firearm-related incidents. By examining these datasets, we can gain a comprehensive understanding of the safety landscape across Pittsburgh neighborhoods.
#
# In measuring the safety of each neighborhood, we first filtered them for 2020 data in order to get a more pinpointed set of data, then we calculated separate ranks for each neighborhood based on the total number of arrests and seizures. Higher numbers of incidents corresponded to higher ranks, indicating areas with higher incident rates. For neighborhoods present in both datasets, we computed a combined rank by summing their individual ranks from both datasets. This approach provided a consolidated view of safety by considering both law enforcement interventions and firearm-related incidents. Finally, based on the combined ranks, we identified the top 3 "safest" neighborhoods with the lowest combined ranks, signifying lower incident rates and higher safety levels.

# %%
import pandas as pd

# %%
arrests = pd.read_csv("arrests.csv")
seizures = pd.read_csv("firearm_seizures.csv")

# %%
#Filter for 2020
arrests_2020 = arrests[arrests['ARRESTTIME'].str.contains('2020', na=False)]
apn_2020 = arrests_2020['INCIDENTNEIGHBORHOOD'].value_counts()

seizures_2020 = seizures[seizures['year'] == 2020]
total_seizures_2020 = seizures_2020.groupby("neighborhood").sum()['total_count']

# %%
# Sort neighborhoods based on totals and assign ranks
sorted_arrests = apn_2020.sort_values().index.tolist()
arrests_ranks = {neighborhood: i+1 for i, neighborhood in enumerate(sorted_arrests)}

sorted_seizures = total_seizures_2020.sort_values().index.tolist()
seizures_ranks = {neighborhood: i+1 for i, neighborhood in enumerate(sorted_seizures)}

# %%
#Combining the ranks from each to find the lowest overall neighborhood
combined_ranks = {}
for neighborhood in set(sorted_arrests).intersection(sorted_seizures):
    combined_ranks[neighborhood] = arrests_ranks[neighborhood] + seizures_ranks[neighborhood]

top_3_safest_neighborhoods = sorted(combined_ranks, key=combined_ranks.get)[:3]
top_3_ranks = [combined_ranks[neighborhood] for neighborhood in top_3_safest_neighborhoods]

print("Top 3 'Safest' Neighborhoods Overall in Pittsburgh for 2020:")
for i, neighborhood in enumerate(top_3_safest_neighborhoods, 1):
    print(f"{i}. {neighborhood}")
# Out:
# Top 3 'Safest' Neighborhoods Overall in Pittsburgh for 2020:
# 1. Chartiers City
# 2. Upper Lawrenceville
# 3. Lincoln Place

# %%
#Showing more detail on the rankings for each set and the final combined set
print("Original Lists with Total Counts, Ranks, and Combined Ranks:")
print("\nArrests (2020):")
for i, neighborhood in enumerate(sorted_arrests, 1):
    print(f"{i}. {neighborhood}: {apn_2020[neighborhood]} arrests, Rank: {arrests_ranks[neighborhood]}")

print("\nSeizures (2020):")
for i, neighborhood in enumerate(sorted_seizures, 1):
    print(f"{i}. {neighborhood}: {total_seizures_2020[neighborhood]} seizures, Rank: {seizures_ranks[neighborhood]}")

# Print combined list with combined ranks for neighborhoods present in both datasets
print("\nCombined List with Combined Ranks (for neighborhoods present in both datasets):")
for i, (neighborhood, rank) in enumerate(combined_ranks.items(), 1):
    print(f"{i}. {neighborhood}: Combined Rank: {rank}")

# Find the top 3 "safest" neighborhoods overall (lowest combined ranks)
top_3_safest_neighborhoods = sorted(combined_ranks, key=combined_ranks.get)[:3]
top_3_ranks = [combined_ranks[neighborhood] for neighborhood in top_3_safest_neighborhoods]

# Print final rankings for top 3 "safest" neighborhoods
print("\nTop 3 'Safest' Neighborhoods Overall in Pittsburgh for 2020:")
for i, neighborhood in enumerate(top_3_safest_neighborhoods, 1):
    print(f"{i}. {neighborhood}: Combined Rank: {top_3_ranks[i-1]}")

# Print neighborhoods that were only in one set
only_in_arrests = set(sorted_arrests) - set(sorted_seizures)
only_in_seizures = set(sorted_seizures) - set(sorted_arrests)

print("\nNeighborhoods Only in Arrests (2020):")
for neighborhood in only_in_arrests:
    print(f"- {neighborhood}")

print("\nNeighborhoods Only in Seizures (2020):")
for neighborhood in only_in_seizures:
    print(f"- {neighborhood}")
# Out:
# Original Lists with Total Counts, Ranks, and Combined Ranks:
#
# Arrests (2020):
# 1. St. Clair: 3 arrests, Rank: 1
# 2. Regent Square: 3 arrests, Rank: 2
# 3. Outside County: 3 arrests, Rank: 3
# 4. New Homestead: 3 arrests, Rank: 4
# 5. Mt. Oliver Boro: 4 arrests, Rank: 5
# 6. Chartiers City: 5 arrests, Rank: 6
# 7. Oakwood: 7 arrests, Rank: 7
# 8. Arlington Heights: 7 arrests, Rank: 8
# 9. East Carnegie: 7 arrests, Rank: 9
# 10. Outside State: 7 arrests, Rank: 10
# 11. Swisshelm Park: 7 arrests, Rank: 11
# 12. Mount Oliver: 8 arrests, Rank: 12
# 13. Ridgemont: 10 arrests, Rank: 13
# 14. Allegheny West: 10 arrests, Rank: 14
# 15. Friendship: 12 arrests, Rank: 15
# 16. Summer Hill: 14 arrests, Rank: 16
# 17. Polish Hill: 14 arrests, Rank: 17
# 18. Fairywood: 14 arrests, Rank: 18
# 19. Hays: 14 arrests, Rank: 19
# 20. Windgap: 17 arrests, Rank: 20
# 21. Spring Garden: 21 arrests, Rank: 21
# 22. Lower Lawrenceville: 21 arrests, Rank: 22
# 23. Upper Lawrenceville: 21 arrests, Rank: 23
# 24. Esplen: 22 arrests, Rank: 24
# 25. Glen Hazel: 22 arrests, Rank: 25
# 26. Morningside: 25 arrests, Rank: 26
# 27. Duquesne Heights: 27 arrests, Rank: 27
# 28. Overbrook: 28 arrests, Rank: 28
# 29. Lincoln Place: 30 arrests, Rank: 29
# 30. Squirrel Hill North: 31 arrests, Rank: 30
# 31. Arlington: 31 arrests, Rank: 31
# 32. West End: 31 arrests, Rank: 32
# 33. Outside City: 34 arrests, Rank: 33
# 34. Westwood: 35 arrests, Rank: 34
# 35. Troy Hill: 35 arrests, Rank: 35
# 36. South Shore: 37 arrests, Rank: 36
# 37. West Oakland: 37 arrests, Rank: 37
# 38. Terrace Village: 37 arrests, Rank: 38
# 39. Chateau: 37 arrests, Rank: 39
# 40. Bon Air: 38 arrests, Rank: 40
# 41. Upper Hill: 40 arrests, Rank: 41
# 42. California-Kirkbride: 41 arrests, Rank: 42
# 43. Stanton Heights: 42 arrests, Rank: 43
# 44. Point Breeze North: 43 arrests, Rank: 44
# 45. South Oakland: 43 arrests, Rank: 45
# 46. Central Lawrenceville: 44 arrests, Rank: 46
# 47. Beltzhoover: 48 arrests, Rank: 47
# 48. Greenfield: 52 arrests, Rank: 48
# 49. Strip District: 52 arrests, Rank: 49
# 50. Banksville: 53 arrests, Rank: 50
# 51. Point Breeze: 54 arrests, Rank: 51
# 52. Central Oakland: 54 arrests, Rank: 52
# 53. North Oakland: 55 arrests, Rank: 53
# 54. North Shore: 58 arrests, Rank: 54
# 55. Crafton Heights: 68 arrests, Rank: 55
# 56. Perry North: 68 arrests, Rank: 56
# 57. Manchester: 76 arrests, Rank: 57
# 58. Elliott: 79 arrests, Rank: 58
# 59. Spring Hill-City View: 88 arrests, Rank: 59
# 60. Bedford Dwellings: 89 arrests, Rank: 60
# 61. Crawford-Roberts: 96 arrests, Rank: 61
# 62. Middle Hill: 97 arrests, Rank: 62
# 63. Larimer: 98 arrests, Rank: 63
# 64. South Side Slopes: 99 arrests, Rank: 64
# 65. Squirrel Hill South: 100 arrests, Rank: 65
# 66. Garfield: 100 arrests, Rank: 66
# 67. Northview Heights: 100 arrests, Rank: 67
# 68. Allentown: 101 arrests, Rank: 68
# 69. Highland Park: 107 arrests, Rank: 69
# 70. Homewood West: 107 arrests, Rank: 70
# 71. Bloomfield: 109 arrests, Rank: 71
# 72. Fineview: 111 arrests, Rank: 72
# 73. Perry South: 112 arrests, Rank: 73
# 74. Central North Side: 113 arrests, Rank: 74
# 75. Mount Washington: 129 arrests, Rank: 75
# 76. Shadyside: 135 arrests, Rank: 76
# 77. Brighton Heights: 143 arrests, Rank: 77
# 78. Beechview: 147 arrests, Rank: 78
# 79. Allegheny Center: 155 arrests, Rank: 79
# 80. Brookline: 160 arrests, Rank: 80
# 81. Knoxville: 166 arrests, Rank: 81
# 82. Lincoln-Lemington-Belmar: 169 arrests, Rank: 82
# 83. East Hills: 172 arrests, Rank: 83
# 84. Marshall-Shadeland: 176 arrests, Rank: 84
# 85. Sheraden: 178 arrests, Rank: 85
# 86. Hazelwood: 180 arrests, Rank: 86
# 87. Bluff: 200 arrests, Rank: 87
# 88. East Liberty: 205 arrests, Rank: 88
# 89. East Allegheny: 239 arrests, Rank: 89
# 90. Carrick: 245 arrests, Rank: 90
# 91. Homewood North: 282 arrests, Rank: 91
# 92. Homewood South: 308 arrests, Rank: 92
# 93. South Side Flats: 344 arrests, Rank: 93
# 94. Central Business District: 543 arrests, Rank: 94
#
# Seizures (2020):
# 1. Lincoln Place: 1 seizures, Rank: 1
# 2. West End: 1 seizures, Rank: 2
# 3. Upper Lawrenceville: 1 seizures, Rank: 3
# 4. South Shore: 1 seizures, Rank: 4
# 5. Shadyside: 1 seizures, Rank: 5
# 6. Point Breeze North: 1 seizures, Rank: 6
# 7. Mt. Oliver: 1 seizures, Rank: 7
# 8. Mount Oliver Borough: 1 seizures, Rank: 8
# 9. Westwood: 1 seizures, Rank: 9
# 10. Esplen: 1 seizures, Rank: 10
# 11. Chateau: 1 seizures, Rank: 11
# 12. Chartiers City: 1 seizures, Rank: 12
# 13. Windgap: 1 seizures, Rank: 13
# 14. Allegheny Center: 2 seizures, Rank: 14
# 15. Arlington: 2 seizures, Rank: 15
# 16. Central Oakland: 2 seizures, Rank: 16
# 17. Upper Hill: 2 seizures, Rank: 17
# 18. Strip District: 2 seizures, Rank: 18
# 19. South Side Slopes: 2 seizures, Rank: 19
# 20. Point Breeze: 2 seizures, Rank: 20
# 21. Lower Lawrenceville: 2 seizures, Rank: 21
# 22. Swisshelm Park: 3 seizures, Rank: 22
# 23. Stanton Heights: 3 seizures, Rank: 23
# 24. Squirrel Hill South: 3 seizures, Rank: 24
# 25. Beltzhoover: 3 seizures, Rank: 25
# 26. Perry North: 3 seizures, Rank: 26
# 27. North Oakland: 3 seizures, Rank: 27
# 28. Larimer: 3 seizures, Rank: 28
# 29. Central Lawrenceville: 3 seizures, Rank: 29
# 30. Morningside: 3 seizures, Rank: 30
# 31. Duquesne Heights: 3 seizures, Rank: 31
# 32. Hays: 3 seizures, Rank: 32
# 33. Troy Hill: 4 seizures, Rank: 33
# 34. Crawford-Roberts: 4 seizures, Rank: 34
# 35. Overbrook: 4 seizures, Rank: 35
# 36. North Shore: 4 seizures, Rank: 36
# 37. California-Kirkbride: 5 seizures, Rank: 37
# 38. Squirrel Hill North: 5 seizures, Rank: 38
# 39. Bedford Dwellings: 5 seizures, Rank: 39
# 40. South Oakland: 5 seizures, Rank: 40
# 41. Bloomfield: 5 seizures, Rank: 41
# 42. Elliott: 5 seizures, Rank: 42
# 43. Garfield: 5 seizures, Rank: 43
# 44. Middle Hill: 5 seizures, Rank: 44
# 45. Marshall-Shadeland: 6 seizures, Rank: 45
# 46. Central Northside: 6 seizures, Rank: 46
# 47. Manchester: 7 seizures, Rank: 47
# 48. Allentown: 7 seizures, Rank: 48
# 49. Bluff: 7 seizures, Rank: 49
# 50. Terrace Village: 7 seizures, Rank: 50
# 51. Mount Washington: 7 seizures, Rank: 51
# 52. East Allegheny: 7 seizures, Rank: 52
# 53. Brookline: 8 seizures, Rank: 53
# 54. Fineview: 8 seizures, Rank: 54
# 55. Crafton Heights: 8 seizures, Rank: 55
# 56. Homewood West: 8 seizures, Rank: 56
# 57. Homewood North: 9 seizures, Rank: 57
# 58. East Hills: 9 seizures, Rank: 58
# 59. Knoxville: 10 seizures, Rank: 59
# 60. Hazelwood: 10 seizures, Rank: 60
# 61. Beechview: 11 seizures, Rank: 61
# 62. Northview Heights: 11 seizures, Rank: 62
# 63. Highland Park: 12 seizures, Rank: 63
# 64. Sheraden: 13 seizures, Rank: 64
# 65. Spring Hill-City View: 14 seizures, Rank: 65
# 66. South Side Flats: 14 seizures, Rank: 66
# 67. Central Business District: 16 seizures, Rank: 67
# 68. Perry South: 19 seizures, Rank: 68
# 69. Lincoln-Lemington-Belmar: 19 seizures, Rank: 69
# 70. Carrick: 21 seizures, Rank: 70
# 71. Homewood South: 24 seizures, Rank: 71
# 72. Brighton Heights: 51 seizures, Rank: 72
# 73. East Liberty: 64 seizures, Rank: 73
#
# Combined List with Combined Ranks (for neighborhoods present in both datasets):
# 1. Arlington: Combined Rank: 46
# 2. Duquesne Heights: Combined Rank: 58
# 3. Knoxville: Combined Rank: 140
# 4. Brighton Heights: Combined Rank: 149
# 5. Highland Park: Combined Rank: 132
# 6. South Side Flats: Combined Rank: 159
# 7. South Shore: Combined Rank: 40
# 8. Carrick: Combined Rank: 160
# 9. Beltzhoover: Combined Rank: 72
# 10. Morningside: Combined Rank: 56
# 11. Overbrook: Combined Rank: 63
# 12. Squirrel Hill North: Combined Rank: 68
# 13. Hazelwood: Combined Rank: 146
# 14. East Allegheny: Combined Rank: 141
# 15. North Oakland: Combined Rank: 80
# 16. Point Breeze: Combined Rank: 71
# 17. Chateau: Combined Rank: 50
# 18. Central Oakland: Combined Rank: 68
# 19. North Shore: Combined Rank: 90
# 20. Middle Hill: Combined Rank: 106
# 21. Marshall-Shadeland: Combined Rank: 129
# 22. Beechview: Combined Rank: 139
# 23. Allegheny Center: Combined Rank: 93
# 24. Shadyside: Combined Rank: 81
# 25. Swisshelm Park: Combined Rank: 33
# 26. Garfield: Combined Rank: 109
# 27. Northview Heights: Combined Rank: 129
# 28. East Liberty: Combined Rank: 161
# 29. Lower Lawrenceville: Combined Rank: 43
# 30. Allentown: Combined Rank: 116
# 31. Squirrel Hill South: Combined Rank: 89
# 32. Crafton Heights: Combined Rank: 110
# 33. Chartiers City: Combined Rank: 18
# 34. Mount Washington: Combined Rank: 126
# 35. Strip District: Combined Rank: 67
# 36. Fineview: Combined Rank: 126
# 37. Lincoln Place: Combined Rank: 30
# 38. Point Breeze North: Combined Rank: 50
# 39. Lincoln-Lemington-Belmar: Combined Rank: 151
# 40. Upper Lawrenceville: Combined Rank: 26
# 41. Hays: Combined Rank: 51
# 42. South Oakland: Combined Rank: 85
# 43. Bluff: Combined Rank: 136
# 44. East Hills: Combined Rank: 141
# 45. Terrace Village: Combined Rank: 88
# 46. Central Business District: Combined Rank: 161
# 47. Homewood West: Combined Rank: 126
# 48. Perry South: Combined Rank: 141
# 49. Windgap: Combined Rank: 33
# 50. Westwood: Combined Rank: 43
# 51. Brookline: Combined Rank: 133
# 52. Elliott: Combined Rank: 100
# 53. Manchester: Combined Rank: 104
# 54. Homewood North: Combined Rank: 148
# 55. Stanton Heights: Combined Rank: 66
# 56. Spring Hill-City View: Combined Rank: 124
# 57. Central Lawrenceville: Combined Rank: 75
# 58. Esplen: Combined Rank: 34
# 59. California-Kirkbride: Combined Rank: 79
# 60. Bedford Dwellings: Combined Rank: 99
# 61. Perry North: Combined Rank: 82
# 62. Sheraden: Combined Rank: 149
# 63. Larimer: Combined Rank: 91
# 64. West End: Combined Rank: 34
# 65. Crawford-Roberts: Combined Rank: 95
# 66. Homewood South: Combined Rank: 163
# 67. Troy Hill: Combined Rank: 68
# 68. Bloomfield: Combined Rank: 112
# 69. South Side Slopes: Combined Rank: 83
# 70. Upper Hill: Combined Rank: 58
#
# Top 3 'Safest' Neighborhoods Overall in Pittsburgh for 2020:
# 1. Chartiers City: Combined Rank: 18
# 2. Upper Lawrenceville: Combined Rank: 26
# 3. Lincoln Place: Combined Rank: 30
#
# Neighborhoods Only in Arrests (2020):
# - Outside City
# - Bon Air
# - Spring Garden
# - Summer Hill
# - Mount Oliver
# - Central North Side
# - Banksville
# - West Oakland
# - Allegheny West
# - Polish Hill
# - Ridgemont
# - New Homestead
# - Greenfield
# - St. Clair
# - Mt. Oliver Boro
# - Friendship
# - Regent Square
# - Arlington Heights
# - Fairywood
# - Outside County
# - Oakwood
# - East Carnegie
# - Outside State
# - Glen Hazel
#
# Neighborhoods Only in Seizures (2020):
# - Mt. Oliver
# - Central Northside
# - Mount Oliver Borough
